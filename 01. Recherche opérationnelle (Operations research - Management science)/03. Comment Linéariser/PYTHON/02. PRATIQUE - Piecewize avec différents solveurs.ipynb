# %% [markdown]
# # Piecewize avec différents solveurs.
#
# # Sommaire :
#
# - Description du problème
# - Dessiner les contraintes PieceWize avec Matplot
# - Avec Cplex
# - Avec Pulp
# - Avec Gekko
# - Avec Excel

# %% [markdown]
# # Description du Problème.
#
# Mon usine produit 2 objets A et B.
#
#
# - Si la production de A > 0, alors le côut de production est de 20
# - Si la production de A > 200, alors le côut de production est de 30
# - Si la production de A > 300, alors le côut de production est de 50
#
# On reconnait là un problème de type piecewize avec des lignes de ce type :
#
# <img src ="img/piecewize.png"></img>

# %% [markdown]
# # Dessiner les contraintes PieceWize avec Matplot

# %%
# On visualise nos contraintes de type piecewize avec les valeurs réelles de notre problème
import matplotlib.pyplot as plt
plt.plot([1, 20, 30, 50], [1, 100, 200, 300])
plt.ylabel('Nombre produits A')
plt.xlabel('coût de production en euros')
plt.show()
