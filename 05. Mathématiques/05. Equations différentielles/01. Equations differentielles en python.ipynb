# %% [markdown]
# # Equations différentielles en python
#
# ## Introduction
#
# Une équation différentielle permet de décrire et analyser des systèmes dynamiques, et non statiques.
# C'est à dire des systèmes en mouvement.
# Une equation différentielle est une équation dont l'inconnue est une fonction.
# On a une ou des solutions qui évoluent en fonction du temps quand on débute, pour comprendre.
# Mais ensuite, ça peut être "en fonction" d'autre chose.
#
# <div style="text-align:center">
# <img src="img/intro.jpg">
# </div>
#
# Notebook réalisé par Github Estelle Derrien
#
# ** En cours de création / Sujet quelques erreurs au début ! Je croise de nombreuses sources en Français et en Anglais pour réaliser ce notebook**
#
# Excellent lien en Anglais : https://quantdev.ssri.psu.edu/sites/qdev/files/ODEintro_tutorial.html
#
# Rappel : y' est une dérivée en notation Lagrange et dy/dx est la notation de la dérivée par Leibniz ( Plutôt en sciences physique)
#
# ## Sommaire:
#
#
# - <b>Introduction.</b>
#
# 1. <b><span style="color:green">Résoudre une équation différentielle d'ordre 1 ->  y' = f</span></b>
#
#     - <b>y' = 2x</b>
#         - Solution Graphique
#         - Solution Symbolique
#
# 2. <b><span style="color:green">Résoudre une équation différentielle d'ordre 1 sans second membre -> y' = ay</span></b>
#
#
#     - <b>y' = 2y</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     -  <b>5y’ + 2y = 0</b>
#         - Solution Symbolique
#             - Déterminer la solution générale de cette équation avec Sympy
#             - Déterminer l’unique solution de l’équation telle que y(1) = 3 avec Sympy
#
#     - <b>3y' + 5y = 0</b>
#         - Solution Symbolique
#             - Déterminer la solution générale de cette équation avec Sympy
#             - Déterminer l’unique solution de l’équation telle que 𝑓(1) = 2 avec Sympy
#     - <b>dy/dt = -yt + 13</b>
#         - Solution Symbolique
#             - Déterminer la solution générale de cette équation avec Sympy
#     - <b>Le problème de Chauchy</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     - <b>Des sin et des cos</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     - <b>Cas pratique 1 : Croissance constante linéaire</b>
#         - Graphiquement.
#         - Solution Symbolique
#
#     - <b>Cas pratique 2 : Croissance avec déclin ( Growth decay)</b>
#         - Suite géométrique
#         - Graphiquement.
#         - Solution Symbolique
#         - Cas pratique :  Croissance de bactéries et interpolation pour résultat numérique exact
#         - Cas pratique : Solution chimique  et temps exact avant de trouver un résultat précis
#         - Cas pratique : Tracer plusieurs eq diffs avec un différent taux k pour comparer.
#
#     - <b>Cas pratique 3 : Croissance de population avec prédation</b>
#         - Graphiquement.
#         - Solution Symbolique
#
#     - <b>Cas pratique 4 : Croissance de population logistique</b>
#         - Graphiquement.
#         - Solution Symbolique
#
#     - <b>Cas pratique 5 : Transfert thermique</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     - <b>Cas pratique 6 : Finances - L'évolution d'un avoir placé à intérêts composés à taux fixe.</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     - <b>Cas pratique 7 : Taux de salinité en reservoir percé</b>
#         - Solution Graphique
#         - Solution Symbolique
#
# 3. <span style="color:green"><b>Résoudre une équation différentielle d'ordre 1 avec second membre constant -> y' = ax + b </b></span>
#
#     - <b>Cas pratique : Température d'une tarte en fonction du temps </b>
#         - Description
#         - Entrer l'équation différentielle dans SYMPY
#         - Trouver la solution générale
#         - Trouver la fonction de la température en fonction du temps grâce à t(0).
#         - Calculer la température de ma tarte après 30 minutes.
# 4. <span style="color:green"><b>Résoudre une équation différentielle d'ordre 1 avec second membre variable -> y' = ax + x² </b></span>
#
#     - <b>Cas Pratique </b>
#         - Description
#         - Solution Symbolique
#         - Solution Graphique
# 5. <span style="color:green"><b>Résoudre une équation différentielle d'ordre 1 avec second membre fonction -> y' = ax + f(x) </b></span>
#
#     - <b>Cas Pratique </b>
#         - Description
#         - Solution Symbolique
#         - Solution Graphique
#
#
# 6. <span style="color:green"><b>Résoudre une équation différentielle d'ordre 2 -> y'' ...</b></span>
#
#     - <b>Exemple 3A</b>
#         - Solution Graphique
#         - Solution Symbolique
#
#     - <b>Exemple 3B</b>
#         - Solution Graphique
#         - Solution Symbolique
#
# 7. <span style color="maroon"><b>Annexes.  Résoudre numériquement une Eq Diff exprimée symboliquement</b></span>
#     - La méthode avec lambdify
#     - https://docs.sympy.org/latest/guides/solving/solve-ode.html

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # <span style="color:grey"> <b>1. Résoudre une équation diff d'ordre 1 -> y' = f</b> </span>

# %% [markdown]
# ## <strong><span style="color:red"> y'=2x<span></strong>
#
#
#
# " On a une fonction dont la dérivée est égale à 2 fois la variable x"
#
# " L’inconnue est la fonction 𝑦 dont la dérivée est égale à 2x "
#
# Lien : https://www.youtube.com/watch?v=qHF5kiDFkW8

# %% [markdown]
# ## Solution Graphique
#
# A vérifier.
#
# les paramêtres de odeint
#
# Differential equations can be solved in Python with the Scipy.integrate package using
# function ODEINT. ODEINT requires three inputs:
# y = odeint(model, y0, t)
# 1. model: Function name that returns derivative values at requested y and t values as
# dydt = model(y,t)
# 2. y0: Initial conditions of the differential states
# 3. t: Time points at which the solution should be reported

# %%
# Import des libs
from scipy import *
from scipy.integrate import odeint #Pour résoudre l’équation différentielle
import matplotlib.pyplot as plt # Permet de tracer des graphes
import numpy as np
from math import *

# %%
# Equation
def deriv (y,x) :
    return 2 * x

#  time points
x = np.linspace ( 0 , 20)

# Condition initiale
y0 = 1

# solve ODE
solution = odeint ( deriv , y0 , x )
y = solution [ : , 0 ]

# plot results
plt.plot ( x , y )
plt.show()

# %% [markdown]
# ## Solution symbolique
#
# ## Etape 1 : Entrer l'eq diff dans Sympy
#
# Ca permet à Sympy d'interpréter l'eq diff.

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = 2 * x

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), 2*x)

# %% [markdown]
# ## Etape 2 : Calculer la solution générale
#
# On calcule les fonctions solution de l'eq diff.
# On trouve bien la même solution que Yvan Monka.

# %%
solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(y(x), C1 + x**2)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # <b><span style="color:grey">2. Résoudre une équation différentielle d'ordre 1 sans second membre -> y' = ay</span></b>

# %% [markdown]
# ## <strong><span style="color:red"> y'=2y<span></strong>
#
# " La dérivée de la fonction y est égale à 2 fois la fonction y"
#
# Lien : https://www.youtube.com/watch?v=qHF5kiDFkW8
# Lien : https://www.maths-et-tiques.fr/telech/20Prim-EdTC.pdf
#
#
# Notation fractionnaire - source https://quantdev.ssri.psu.edu/sites/qdev/files/ODEintro_tutorial.html
#
# \begin{cases}
# \frac{dx}{dt}
# = 2 x(t)
# \end{cases}

# %% [markdown]
# ## Solution Graphique
#
# A vérifier

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Etat du système à t0  
z0 = np.array([1])
alpha = 2

f = lambda t, z : alpha * z

# Timespan = intervalle de temps étudiée t_span - a tuple (t0, t1) which gives the start and end times of the simulation
t_span = (0, 100)
t_eval = np.linspace(0,4, 100)

sol = solve_ivp(f, t_span, z0, t_eval=t_eval)
    
plt.plot(sol.t, sol.y[0], c='k')
plt.title("y' = 2y")
plt.ylabel("y")
plt.xlabel("x")
plt.show()

# %% [markdown]
# ## Solution symbolique
#
# ## Etape 1 : Entrer l'eq diff dans Sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = 2 * y(x)

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), 2*y(x))

# %% [markdown]
# ## Etape 2 : Calcul de la Solution générale
#
# L'equation différentielle est au format y' = ay
#
# On trouve bien la même solution que Yvan Monka.
#
# Les solutions de l'equation différentielle sont les fonctions suivantes:

# %%
solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(y(x), C1*exp(2*x))

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## <strong><span style="color:red">5y' + 2y =0<span></strong>
#
# Lien :  https://www.letudiant.fr/lycee/methodologie-lycee/article/equations-differentielles-entrainez-vous-avec-nos-exercices-corriges.html
#
# <center><img src="img/pb.png"></center>

# %% [markdown]
# ## Déterminer la solution générale de cette équation avec Sympy
#
#
#
# On la mets d'abord au format "standard" avec la dérivée à gauche :
#
# \begin{cases}
# y'= -2 * y / 5
# \end{cases}

# %% [markdown]
# ## Etape 1 : Entrer l'eq diff dans Sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = -2 * y(x) / 5 # La fonction y s'écrit y(x)

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), -2*y(x)/5)

# %% [markdown]
# ## Etape 2 : Calcul de la Solution générale
#
# L’ensemble des solutions s’écrit sous la forme yc(x) = Ce *a.x , C appartient à R
# On trouve bien la même solution que dans le magazine l'étudiant.

# %%
solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(y(x), C1*exp(-2*x/5))

# %% [markdown]
# ## Déterminer l’unique solution de l’équation telle que y(1) = 3 avec Sympy
#
# Autrement dit, déterminer l'unique fonction solution de l'équation différentielle, quand y(1) = 3
#
# ## Etape 1 :  Entrer la condition
#
# La condition est une constante.

# %%
x0 = 1
y1 = 3
consts = sympy.solve( sympy.Eq( y1, solgen.rhs.subs(x,x0)) , dict=True)[0]
consts
# Out:
# {C1: 3*exp(2/5)}

# %% [markdown]
# ## Etape 2 : Calculer La solution unique avec la constante
#
# On prends en compte la constante définie précédemment.
# On voit qu'on trouve la même solution que dans l'exercice .

# %%
solpar = solgen.subs(consts)

display("Unique solution telle que 𝑓(1) = 3")
solpar
# Out:
# 'Unique solution telle que 𝑓(1) = 3'
# Eq(y(x), 3*exp(2/5)*exp(-2*x/5))

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## <strong><span style="color:red"> 3𝑦' + 5𝑦 = 0<span></strong>
#
# On considère l’équation différentielle 3𝑦' + 5𝑦 = 0.
#
# - 1) Déterminer la forme générale des fonctions solutions de l’équation.
#
# - 2) Déterminer l’unique solution 𝑓 telle que 𝑓(1) = 2.
#
# Lien : https://www.maths-et-tiques.fr/telech/20Prim-EdTC.pdf
#
# On retrouve le même résultat !

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = -5 * y(x) / 3 # La fonction y s'écrit y(x)

edo = sympy.Eq( left , right )
display(" Affichage de l'eq diff",edo)

solgen = sympy.dsolve(edo,y(x)) 
display(" Solution générale",solgen)

x0 = 1
y1 = 2
consts = sympy.solve( sympy.Eq( y1, solgen.rhs.subs(x,x0)) , dict=True)[0]
consts
solpar = solgen.subs(consts)
display("Unique solution telle que 𝑓(1) = 2")
solpar
# Out:
# " Affichage de l'eq diff"
# Eq(Derivative(y(x), x), -5*y(x)/3)
# ' Solution générale'
# Eq(y(x), C1*exp(-5*x/3))
# 'Unique solution telle que 𝑓(1) = 2'
# Eq(y(x), 2*exp(5/3)*exp(-5*x/3))

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## <strong><span style="color:red"> dy/dt = -yt + 13<span></strong>
#
# \begin{cases}
# \frac{dy}{dt}
# = -yt + 13
# \end{cases}
#
# ## Résoudre graphiquement

# %%
import numpy as np 
from scipy.integrate import odeint 
import matplotlib.pyplot as plt 
  
def returns_dydt(y,t): 
    dydt = -y * t + 13
    return dydt 
  
# initial condition 
y0 = 1
  
# values of time 
t = np.linspace(0,5) 
  
# solving ODE 
y = odeint(returns_dydt, y0, t) 
  
# plot results 
plt.plot(t,y) 
plt.xlabel("Time") 
plt.ylabel("Y") 
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Le problème de Cauchy:
#
#
# \begin{cases}
# u'(x)=-3x^2u(x)+6x^2,\\
# u(0)=4.
# \end{cases}
#
# On remarque que maintenant, il y a une condition initiale, c'est pour cela qu'on l'appelle " Problème de Cauchy".

# %% [markdown]
# ## Solution Graphique (Numérique)

# %%
# Import des libs
from scipy import *
from scipy.integrate import odeint #Pour résoudre l’équation différentielle
import matplotlib.pyplot as plt # Permet de tracer des graphes
import numpy as np
from math import *

# %%
# Equation
def deriv (y,x) :
    return 6*x**2 - 3*x**2 * y

# Choix de l’ intervalle d’intégration
x0 = 0
xmax = 20
npoints = 1000
x = np.linspace ( x0 , xmax , npoints )

# Condition initiale
y0 = 4 # y(x0) = y0

solution = odeint ( deriv , y0 , x )
y = solution [ : , 0 ]

plt.plot ( x , y )
plt.show ( )

# %% [markdown]
# ## Solution Symbolique
#
# Le problème de Cauchy:
# \begin{cases}
# u'(x)=-3x^2u(x)+6x^2,\\
# u(0)=4.
# \end{cases}

# %% [markdown]
# ## Etape 1 : Entrer l'eq diff dans Sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
u   = sympy.Function('u')

left  = sympy.diff(u(x),x)

right = 6*x**2 - 3*x**2 * u(x)

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(u(x), x), -3*x**2*u(x) + 6*x**2)

# %% [markdown]
# ## Etape 2 : Calculer la solution générale

# %%
solgen = sympy.dsolve(edo,u(x)) 
display(solgen)
# Out:
# Eq(u(x), C1*exp(-x**3) + 2)

# %% [markdown]
# ## Etape 3 : Prendre en compte les conditions initiale

# %%
x0 = 0
u0 = 4
consts = sympy.solve( sympy.Eq( u0, solgen.rhs.subs(x,x0)) , dict=True)[0]
consts
# Out:
# {C1: 2}

# %% [markdown]
# ## Etape 4 : Solution avec les conditions initiales

# %%
solpar = solgen.subs(consts)
solpar
# Out:
# Eq(u(x), 2 + 2*exp(-x**3))

# %% [markdown]
# ## Etape 5 : Solution graphique

# %%
func = sympy.lambdify(x,solpar.rhs,'numpy')
from matplotlib.pylab import *
# rcdefaults()
rcParams.update({'font.size': 16})
figure(figsize=(10,7))
xx=linspace(0,3,101)
yy=func(xx)
plot(xx,yy)
xlabel('x')
ylabel('u')
grid()

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# ## Des sin et des cos
#
# \begin{cases}
# t'(x)=sin(t) * sin(x)
#
# \end{cases}

# %% [markdown]
#  ## Solution Graphique

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def f(x, t):
    return np.sin(t) * np.sin(x)
t = np.linspace(0, 50, 256)
x = odeint(f, 1, t)
plt.plot(t, x)
plt.title("solution de x'=sin(t)sin(x)")
plt.show()

# %% [markdown]
# ## Solution symbolique
#
# ## Etape 1 : Entrer l'eq diff dans Sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x) # Partie gauche, avec la dérivée

right = sympy.sin(y(x)) * sympy.sin(x) # Partie droite, avec les sin et cos qui fonctionnent.

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), sin(x)*sin(y(x)))

# %% [markdown]
# # Cas pratique 1 :  Croissance constante linéaire

# %% [markdown]
# ## Description
#
# Cette forme de croissance est la plus simple et nous offre un excellent moyen de nous entraîner à traduire la théorie en mathématiques.
#
# Supposons que nous ayons une théorie selon laquelle une variable change de manière constante. Par exemple, nous pourrions modéliser le montant d’argent sur un compte d’épargne, si 10 euros étaient <b>ajoutés</b> chaque jour. La variation du solde du compte est toujours de 10 euros/jour, quels que soient les soldes passés ou actuels.
#
# Voici la représentation mathématique:
#
# \begin{cases}
# \frac{dx}{dt}
# = 10
# \end{cases}
#
# Ou dt est une journée.
#
# On peut l'écrire y' = 10 ( A vérifier)

# %% [markdown]
# ## Solution graphique

# %%
# Equation
def deriv (y,x) :
    return 10

# Choix de l’ intervalle d’intégration
x0 = 0
xmax = 20
npoints = 1000
x = np.linspace ( x0 , xmax , npoints )

# Condition initiale
y0 = 1

solution = odeint ( deriv , y0 , x )
y = solution [ : , 0 ]

plt.plot ( x , y )
plt.title("Compte épargne")
plt.ylabel("montant")
plt.xlabel("jours")
plt.show ( )

# %% [markdown]
# ## Solution symbolique

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = 10


edo = sympy.Eq( left , right )
display(edo)

print("solution générale")

solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(Derivative(y(x), x), 10)
# solution générale
# Eq(y(x), C1 + 10*x)

# %% [markdown]
# ## Cas pratique 2 : Croissance avec déclin ( Growth decay)</b>
#
# Ce modèle est le modèle le plus simple qui propose que le changement dans un système soit relatif à la variable d'intérêt. Le modèle de croissance/décroissance proportionnelle s’écrit :
#
# \begin{cases}
# \frac{dx}{dt}
# = ax
# \end{cases}
#
# Mais on la retrouve écrite aussi comme ça : y' = ax
#
# Où a est une constante. Si a est positif, le système croît proportionnellement à lui-même. Si a est négatif, le système se désintègre proportionnellement à lui-même.
#
# Par exemple, les études démographiques offrent une application intuitive de la croissance proportionnelle. Supposons que nous commencions avec une population de lapins. En supposant des ressources illimitées, les lapins se reproduisent avec une portée moyenne. Cela conduit à de nouvelles générations de lapins, qui se reproduisent également, ce qui signifie qu’à mesure que la population augmente, le taux de croissance augmente également.
#
#
# Source : https://quantdev.ssri.psu.edu/sites/qdev/files/ODEintro_tutorial.html
#
# ## Example des lapins
#
# Supposons qu'on ait 100 lapins au temps t0 ( Condition initiale = 100) et que le taux de croissance soit défini par
#
# \begin{cases}
# \frac{dx}{dt}
# = 0.2x
# \end{cases}
# cela veut dire que la population augmente de 20% a chaque intervalle de temps.
#
# # Solution sous forme suite géométrique
#
# Jour 1 : ( 20 / 100 * 100 ) + 100  = 120
#
#
# Jour 2 : ( 20 / 100 * 120 ) + 120 = 144
#
#
# Jour 3 : ( 20 / 100 * 144 ) + 144 = 172.8
#
# Jour 4 : ( 20 / 100 * 172.8 ) + 172.8 = 207.36
#
#
# Maintenant, on veut savoir comment va évoluer la population
#  - Graphiquement
#  - Symboliquement
#
#  ## Solution graphique
#
# Donc là, on résouds, comme dans les exemples du début notebook, l'equation diff y' = 0.2x,
# on voit qu'on trouve pareil que dans la suite géométrique calculée au dessus.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Etat du système à t0  
z0 = np.array([100]) # On débute avec 100 lapins
alpha = 0.2 # Le taux

f = lambda t, z : alpha * z

# Timespan = intervalle de temps étudiée t_span - a tuple (t0, t1) which gives the start and end times of the simulation
t_span = (0, 100)
t_eval = np.linspace(0,4, 100)

sol = solve_ivp(f, t_span, z0, t_eval=t_eval)
    
plt.plot(sol.t, sol.y[0], c='k')
plt.title("Population de lapins")
plt.ylabel("lapins")
plt.xlabel("jours")
plt.show()

# %%
# Taux
k = 0.2

# Equation
def deriv (y,x) :
    return y * k

#  Time points
x = np.linspace ( 0 , 4)

# Condition initiale
y0 = 100

# Résoudre l'équation diff
solution = odeint ( deriv , y0 , x )
y = solution [ : , 0 ]

# Dessiner le résultat
plt.plot ( x , y )
plt.show()

# %% [markdown]
# ## Cas pratique : Croissance de bactéries et interpolation pour résultat exact
#
# au début de l'expérimentation, il y a 100 bactéries. Si les bactéries suivent un modèle de croissance avec un taux k = 0.2,
# trouver la population après 5 heures, puis après 10 heures.

# %%
# Taux
k = 0.2

# Equation
def deriv (y,x) :
    return y * k

#  Time points
x = np.linspace ( 0 , 10)

# Condition initiale
y0 = 100

# Résoudre l'équation diff
solution = odeint ( deriv , y0 , x )
y = solution [ : , 0 ]


# Dessiner le résultat
plt.plot ( x , y )

plt.show()


# Trouver la valeur des bactéries au temps 5
print(" au temps 5, ma populaton sera de " ,np.interp(5, x, y))


# Trouver la valeur des bactéries au temps 10
print(" au temps 10, ma populaton sera de " ,np.interp(10, x, y))
# Out:
#  au temps 5, ma populaton sera de  271.88479583410134
#  au temps 10, ma populaton sera de  738.905626502641

# %% [markdown]
# # Interpolation
#
# Trouver au bout de combien de temps la valeur de y se réduira à 1
#
# https://kitchingroup.cheme.cmu.edu/blog/2011/08/31/Solving-an-ode-for-a-specific-solution-value/
#
#
# The analytical solution to an ODE is a function, which can be solved to get a particular value, e.g. if the solution to an ODE is y(x) = exp(x), you can solve the solution to find the value of x that makes y(x)=2
#
# . In a numerical solution to an ODE we get a vector of independent variable values, and the corresponding function values at those values. To solve for a particular function value we need a different approach. This post will show one way to do that in python.
#
# Given that the concentration of a species A in a constant volume, batch reactor obeys this differential equation dCAdt=−kC2A
# with the initial condition CA(t=0)=2.3 mol/L and k=0.23 L/mol/s, compute the time it takes for CA
#
# to be reduced to 1 mol/L.
#
# We will get a solution, then create an interpolating function and use fsolve to get the answer.

# %%
from scipy.integrate import odeint
from scipy.interpolate import interp1d
from scipy.optimize import fsolve
import numpy as np
import matplotlib.pyplot as plt

k = 0.23
Ca0 = 2.3

def dCadt(Ca, t):
    return -k * Ca**2

tspan = np.linspace(0, 10)

sol = odeint(dCadt, Ca0, tspan)
Ca = sol[:,0]

plt.plot(tspan, Ca)
plt.xlabel('Time (s)')
plt.ylabel('$C_A$ (mol/L)')


ca_func = interp1d(tspan, Ca, 'cubic')

itime = np.linspace(0, 10, 200)

plt.figure()
plt.plot(tspan, Ca, '.')
plt.plot(itime, ca_func(itime), 'b-')

plt.xlabel('Time (s)')
plt.ylabel('$C_A$ (mol/L)')
plt.legend(['solution','interpolated'])

plt.show()

# %%
tguess = 2.0
tsol, = fsolve(lambda t: 1.0 - ca_func(t), tguess)
print (tsol)
# Out:
# 2.4574668234994648

# %% [markdown]
# ## Cas pratique : Tracer plusieurs eq diffs avec un différent taux k pour comparer.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# function that returns dy/dt
def model(y,t,k):
    dydt = -k * y
    return dydt
# initial condition
y0 = 5
# time points
t = np.linspace(0,20)
# solve ODEs
k = 0.1
y1 = odeint(model,y0,t,args=(k,))
k = 0.2
y2 = odeint(model,y0,t,args=(k,))
k = 0.5
y3 = odeint(model,y0,t,args=(k,))
# plot results
plt.plot(t,y1,'r-',linewidth=2,label='k=0.1')
plt.plot(t,y2,'b--',linewidth=2,label='k=0.2')
plt.plot(t,y3,'g:',linewidth=2,label='k=0.5')
plt.xlabel('time')
plt.ylabel('y(t)')
# Out:
# Text(0, 0.5, 'y(t)')

# %% [markdown]
# ## Retour aux lapins : Solution symbolique avec SYMPY
#
# Etape 1 : Entrer l'eq diff dans Sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = 0.02 * x

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), 0.02*x)

# %% [markdown]
# Etape 2 : Trouver la solution générale de l'eq diff

# %%
solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(y(x), C1 + 0.01*x**2)

# %% [markdown]
# Etape 3 : Savoir combien on a de lapins au jour 4

# %% [markdown]
# # Cas pratique 3 : Croissance de population avec prédation
#
# A venir

# %% [markdown]
# # Cas pratique 4  : Croissance de population logistique
#
# Voici les 3 méthodes de calcul apparentées sur ce sujet :
#
# A venir ....

# %% [markdown]
# # <span style="color:grey">3. Résoudre une équation différentielle d'ordre 1 avec second membre <b>constant</b> -> y' = ax + b</span>
#
# ## Cas pratique
#
# Source : https://www.youtube.com/watch?v=3X1m6triQzA
#
# Je viens de sortir ma tarte à la morue du four.
# Sa température est de 200 degrés.
# Je remarque que sa température est fonction du temps T(t) en heure et suit une équation différentielle
# y' + 1.4y = 30
#
# a/ Donnez l'expression de g(t) en fonction de t , c'est à dire , résoudre l'équation différentielle
#
# b/ Quelle sera la température de ma tarte après 30 minutes ?

# %%
# Etape 0
# On mets l'eq diff au format y' = ay + b
# y' = -1.4y + 30

# %% [markdown]
# # Etape 1 : Entrer l'équation différentielle dans sympy

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x
import sympy

x   = sympy.Symbol('x')
y   = sympy.Function('y')

left  = sympy.diff(y(x),x)

right = -1.4 * y(x) + 30

edo = sympy.Eq( left , right )
display(edo)
# Out:
# Eq(Derivative(y(x), x), 30 - 1.4*y(x))

# %% [markdown]
# # Etape 2 : Afficher la solution générale

# %%
solgen = sympy.dsolve(edo,y(x)) 
display(solgen)
# Out:
# Eq(y(x), C1*exp(-1.4*x) + 21.4285714285714)

# %% [markdown]
# # Etape 3 : Déterminer l’unique solution de l’équation telle que T(0) = 200 avec Sympy
#
# Comme explique le prof, on doit utiliser cette technique pour ensuite obtenir une équation qui nous permettre de savoir la température à tout temps donné. On sait qu'au temps 0, quand on la sort du four, elle est de 200 degrés.
#
# Il faut Entrer la condition, La condition est une constante.

# %%
x0 = 0
y1 = 200
consts = sympy.solve( sympy.Eq( y1, solgen.rhs.subs(x,x0)) , dict=True)[0]
consts
# Out:
# {C1: 178.571428571429}

# %% [markdown]
# # Etape 4 : Equation de la température de ma tarte en fonction du temps
#
# Grace aux 3 étapes précédentes, on sait que pour trouver la température de ma tarte en fonction du temps en heure,
# l'équation est :

# %%
solpar = solgen.subs(consts)
solpar
# Out:
# Eq(y(x), 21.4285714285714 + 178.571428571429*exp(-1.4*x))

# %% [markdown]
# # Etape 5 : Quelle sera la température de ma tarte après 30 minutes ?
#
# On se sert de l'équation trouvée à l'étape 4, pour trouver la température !
# Vu que c'est en heure, 30 minutes = 0.5 heures !

# %%
import math 
temperature = 21.42 + 178.572 * math.exp(-1.4 * 0.5)
print(" La température de ma tarte au bout de 30 minutes sera de ",temperature," degrés")
# Out:
#  La température de ma tarte au bout de 30 minutes sera de  110.09623086863958  degrés

# %% [markdown]
# # <span style="color:grey">4. Résoudre une équation différentielle d'ordre 1 avec second membre variable -> y' = ax + x²</span>

# %% [markdown]
# Source : https://www.youtube.com/watch?v=Xd9bKiQgzp8
#
# y' - 2y = x²
#
# On le fait en 2 étapes, d'abord, on trouve la solution générale de l'équation homogène, puis une solution particulière de l'équation d'origine, puis on additionne la deux pour trouver la solution.
#
# ## Etape 1 : Trouver la solution générale de l'équation homogène y' - 2y = 0
