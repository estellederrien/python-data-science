# %%
import matplotlib.pyplot as plt
import numpy 
import pandas

# Réaliser des stats sur un fichier de ventes de black friday .
black_friday = pandas.read_csv("BlackFriday.csv")

# Seaborn a pour avantage de prendre directement les noms de colonnes .
import seaborn as sns
sns.boxplot(x="Gender",y="Purchase",hue="Gender",data = black_friday,palette = "Set1")
plt.draw()

# %%
# Achats par catégorie d'age ET par genre à l'aide de hue
sns.boxplot(x="Gender",y="Purchase",hue="Age",data = black_friday,palette = "Set1")
plt.draw()

# %%
# countplot
sns.countplot(x="Age",hue="Gender",data = black_friday,palette = "Set1")
plt.draw()

# %%
# Générer un subset aléatoire d'un jeu de données
subset = black_friday.sample(1000)
subset
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 184162  1004404  P00301542      M  26-35           1             B
# 472681  1000854  P00016042      F  26-35          16             B
# 82938   1000824  P00331242      M  36-45          12             A
# 363814  1001963  P00210042      F  51-55           9             C
# 68794   1004508  P00045642      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 513818  1001170  P00126042      M    55+           3             A
# 333427  1003401  P00113042      M  36-45           7             B
# 407845  1002811  P00279842      M  26-35          19             B
# 38993   1006009  P00118042      F  26-35          12             C
# 331485  1003099  P00312742      M  26-35          17             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 184162                          1               0                  16
# ...

# %%
sns.catplot(x="Age",y="Purchase",data = subset)
plt.draw()

# %%
sns.catplot(x="Age",y="Purchase",data = subset,kind="swarm")
plt.draw()

# %%
# On visualise le genre
sns.catplot(x="Age",y="Purchase",hue="Gender",data = subset,kind="swarm")
plt.draw()

# %%
#Combiner des graphiques
plt.subplot(211)
sns.countplot(x="Age",hue="Gender",data = black_friday,palette = "Set1")
plt.subplot(212)
sns.boxplot(x="Gender",y="Purchase",hue="Age",data = black_friday,palette = "Set1")
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.draw()
