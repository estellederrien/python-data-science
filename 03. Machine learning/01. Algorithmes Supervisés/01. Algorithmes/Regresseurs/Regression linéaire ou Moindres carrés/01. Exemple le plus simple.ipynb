# %% [markdown]
# # La regression linéaire avec skLearn
# Aussi appellée "les moindres carrés"
#
# y = ax + b
#
# la regression trouve les paramètres a(pente de la courbe) et b qui est le décalage vis à vis de y, qui minimisent la moyenne des erreurs des moindres carrés entre les prédictions et les valeurs réelles

# %%
# Import the packages and classes needed in this example:
import numpy as np
from sklearn.linear_model import LinearRegression

# Create a numpy array of data:
x = np.array([6, 16, 26, 36, 46, 56]).reshape((-1, 1))
y = np.array([4, 23, 10, 12, 22, 35])

# Create an instance of a linear regression model and fit it to the data with the fit() function:
model = LinearRegression().fit(x, y) 

# The following section will get results by interpreting the created instance: 

# Obtain the coefficient of determination by calling the model with the score() function, then print the coefficient:
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)

# Print the Intercept:
print('intercept:', model.intercept_)

# Print the Slope:
print('slope:', model.coef_) 

# Predict a Response and print it:
y_pred = model.predict(x)
print('Predicted response:', y_pred, sep='\n')
# Out:
# coefficient of determination: 0.5417910447761195
# intercept: 4.026666666666664
# slope: [0.44]
# Predicted response:
# [ 6.66666667 11.06666667 15.46666667 19.86666667 24.26666667 28.66666667]

# %% [markdown]
# Tracer la régression linéaire

# %%
# Import the packages and classes needed for this example:
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create random data with numpy, and plot it with matplotlib:
rnstate = np.random.RandomState(1)
x = 10 * rnstate.rand(50)
y = 2 * x - 5 + rnstate.randn(50)
plt.scatter(x, y);
plt.show()

# Create a linear regression model based the positioning of the data and Intercept, and predict a Best Fit:
model = LinearRegression(fit_intercept=True)
model.fit(x[:, np.newaxis], y)
xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

# Plot the estimated linear regression line with matplotlib:
plt.scatter(x, y)
plt.plot(xfit, yfit);
plt.show()

# %% [markdown]
# Concepts clefs :
#
# Meilleur ajustement - la ligne droite dans un tracé qui minimise l'écart entre les points de données dispersés liés.
#
#     Coefficient - également appelé paramètre, est le facteur par lequel une variable est multipliée. Dans la régression linéaire, un coefficient représente les changements dans une variable de réponse (voir ci-dessous).
#
#     Coefficient de détermination – le coefficient de corrélation noté 𝑅². Utilisé pour décrire la précision ou le degré d'ajustement dans une régression.
#
#     Corrélation – la relation entre deux variables en termes de force et de degré quantifiables, souvent appelée « degré de corrélation ». Les valeurs sont comprises entre -1,0 et 1,0.
#
#     Caractéristique dépendante - une variable notée y dans l'équation de pente y=ax+b. Aussi connu sous le nom de sortie ou de réponse.
#
#     Ligne de régression estimée - la ligne droite qui correspond le mieux à un ensemble de points de données dispersés.
#
#     Caractéristique indépendante – une variable notée x dans l'équation de pente y=ax+b. Aussi connu sous le nom d'entrée ou de prédicteur.
#
#     Interception – l'emplacement où la pente intercepte l'axe Y noté b dans l'équation de pente y=ax+b.
#
#     Moindres carrés - une méthode d'estimation d'un meilleur ajustement aux données, en minimisant la somme des carrés des différences entre les valeurs observées et estimées.
#
#     Moyenne - une moyenne d'un ensemble de nombres, mais en régression linéaire, la moyenne est modélisée par une fonction linéaire.
#
#     Régression des moindres carrés ordinaires (OLS) - plus communément appelée régression linéaire.
#
#     Résiduel - distance verticale entre un point de données et la ligne de régression (voir Résiduel dans la Figure 1 ci-dessous).
#
#     Régression - estimation du changement prédictif d'une variable par rapport aux changements d'autres variables (voir la réponse prédite dans la figure 1 ci-dessous).
#
#     Modèle de régression - la formule idéale pour approximer une régression.
#
#     Variables de réponse - comprend à la fois la réponse prévue (la valeur prédite par la régression) et la réponse réelle, qui est la valeur réelle du point de données (voir la figure 1 ci-dessous).
#
#     Pente - la pente d'une ligne de régression.
#
#     Slope et Intercept peuvent être utilisés pour définir la relation linéaire entre deux variables : y=ax+b.
#
#     Régression linéaire simple - une régression linéaire qui a une seule variable indépendante.
