# %% [markdown]
# Ecrire du HTML dans un notebook python : <br>
# This is an example of an *italic* text.<br><br>
# This is an example of a **bold*** text.<br>
# This is an example of a list item:
# - Item #1
# - Item #2
# - Item #3
# ---

# %%
# Créer des graphiques
import numpy as np
import math
import matplotlib.pyplot as plt
x = np.linspace(0, 2*math.pi)
plt.plot(x, np.sin(x), label=r'$\sin(x)$')
plt.plot(x, np.cos(x), 'ro', label=r'$\cos(x)$')
plt.title(r'Two plots in a graph')
plt.legend()

# %% [markdown]
# # Ecrire des fonctions de maths avec latex
# $$N(x) = \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{-\frac{z^2}{2}}\, dz$$

# %%
# Ecrire des fonctions de maths avec la lib MATH
from IPython.display import Math
Math(r'N(x) = \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{-\frac{z^2}{2}}\, dz')
# Out:
# $\displaystyle N(x) = \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{-\frac{z^2}{2}}\, dz$

# %%
# Afficher des images :
from IPython.display import Image
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
# Importer des vidéos :
from IPython.lib.display import YouTubeVideo
# An introduction to Python by Google.
YouTubeVideo('tKTZoB2Vjuk')

# %%
# Carrément créer une table en HTML dans le notebook : 
from IPython.display import HTML
table = """<table>
<tr>
<th>Header 1</th>
<th>Header 2</th>
</tr>
<tr>
<td>row 1, cell 1</td>
<td>row 1, cell 2</td>
</tr>
<tr>
<td>row 2, cell 1</td>
<td>row 2, cell 2</td>
</tr>
</table>"""
HTML(table)
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
